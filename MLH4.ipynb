# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavika2222/mission_first/blob/master/MLH4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#MLH Assignment: 4

#Text classification: Sentimental analysis using KNN on Twitter data

#Train dataset renamed as train.csv after download
#https://www.kaggle.com/code/kerneler/starter-twitter-sentiment-analysis-257d5754-1/data?select=train_E60V3IV.csv

#Test dataset renamed as test.csv after download

#https://www.kaggle.com/code/kemeler/starter-twitter-sentiment-analysis-257d5754-1/data?select=test_tweets_anuFYb8.csv


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords_list = stopwords.words("english")
print(stopwords_list)

train = pd.read_csv(r"train_E6oV3lV.csv")
test = pd.read_csv(r"test_tweets_anuFYb8.csv")
label = train['label']
train.drop(['label'], axis=1, inplace=True)
combi = pd.concat([train, test], ignore_index=True)
tweets = combi['tweet']
import re
from nltk.corpus import stopwords
tweets = tweets.str.lower()
tweets = tweets.apply(lambda x: re.sub("[^a-z\s]","",x))

tweets = tweets.str.replace("#", "")

tweets = tweets.apply(lambda x:''.join([w for w in x.split() if len(w)>2]))

stopwords=set(stopwords.words("english"))
tweets = tweets.apply(lambda x: "".join(word for word in x.split() if word not in stopwords))
most_freq_words = pd.Series(''.join(tweets).lower().split()).value_counts()[:25]
tweets=tweets.apply(lambda x: "".join(word for word in x.split() if word not in most_freq_words))
print("Before most_freq_words calculation")
most_freq_words = pd.Series(''.join(tweets).lower().split()).value_counts()[:25]
print("After most_freq_words calculation")
print(most_freq_words)


from collections import Counter
from itertools import chain

v = tweets.str.split().tolist()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...
