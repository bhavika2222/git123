# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavika2222/mission_first/blob/master/DL2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import the necessary packages
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# Load the MNIST dataset and normalize the pixel values
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# Define and compile the model
model = models.Sequential([layers.Flatten(input_shape=(28, 28)), layers.Dense(128, 'relu'), layers.Dense(10, 'softmax')])
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model and store history
history = model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

# Evaluate and print the test accuracy
print(f'Test accuracy: {model.evaluate(test_images, test_labels)[1]}')

# Plot training loss and accuracy
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.6426 - accuracy: 0.8375 - val_loss: 0.3539 - val_accuracy: 0.9053
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3363 - accuracy: 0.9058 - val_loss: 0.2947 - val_accuracy: 0.9173
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2891 - accuracy: 0.9186 - val_loss: 0.2623 - val_accuracy: 0.9263
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2589 - accuracy: 0.9271 - val_loss: 0.2403 - val_accuracy: 0.9349
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2359 - accuracy: 0.9343 - val_loss: 0.2182 - val_accuracy: 0.9381
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2173 - accuracy: 0.9395 - val_loss: 0.2049 - val_accuracy: 0.9411
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2015 - accuracy: 0.9437 - val_loss: 0.1895 - val_accuracy: 0.9454
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1883 - accuracy: 0.9468 - val_loss: 0.1815 - val_accuracy: 0.9486
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1767 - accuracy: 0.9504 - val_loss: 0.1709 - val_accuracy: 0.9508
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1666 - accuracy: 0.9530 - val_loss: 0.1646 - val_accuracy: 0.9515
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1646 - accuracy: 0.9515
# Test accuracy: 0.9514999985694885
