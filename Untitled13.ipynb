# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavika2222/git123/blob/master/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset from a CSV file
df = pd.read_csv('/heart.csv')

# Correlation heatmap
plt.figure(figsize=(15, 6))
sns.heatmap(df.corr(), annot=True)
plt.title('Degree of Correlation of variables in the dataset')

# Chances of heart disease
plt.figure(figsize=(15, 6))
sns.countplot(x='target', data=df)
plt.xticks([0, 1], ['less chance', 'more chance'])
plt.title('Chances of heart disease')

# Number of males and females
plt.figure(figsize=(15, 6))
sns.countplot(x='sex', data=df)
plt.title('Number of males and females')
plt.xticks([0, 1], ['females', 'males'])

# Chances of heart disease by gender
plt.figure(figsize=(15, 6))
sns.countplot(x='sex', data=df, hue='target')
plt.title('Chances of heart disease by gender')
plt.xticks([0, 1], ['females', 'males'])
plt.legend(labels=['less chance', 'high chance'])

# Distribution of chest pain types
plt.figure(figsize=(10, 6))
sns.histplot(df['cp'])
plt.xticks([0, 1, 2, 3], ["typical angina", "atypical angina", "non-anginal pain", "asymptomatic"])
plt.xticks(rotation=70)

# Rest of the visualizations...

plt.show()
